# %% [markdown]
# #**ETS Exercise**

# %% [markdown]
# ## ETS Decomposition of Airline Passengers Dataset:

# %% [markdown]
# ## Import libraries

# %% [markdown]
# ## Read dataset

# %% [markdown]
# ## show dataset

# %% [markdown]
# ## Apply ETS

# %% [markdown]
# ## Plot ETS

# %% [markdown]
# ## **Well done :)**
